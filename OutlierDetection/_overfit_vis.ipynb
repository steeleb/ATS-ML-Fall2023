# %% [markdown]
# Some quick visualizations of the model output

# %%
#high level modules
import os
import sys
import imp
import numpy as np
import pandas as pd
import pickle

# ml/ai modules
import tensorflow as tf
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
# import pydot
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.colors as colors

# custom modules
this_dir = "/Users/steeleb/Documents/GitHub/ATS-ML-Fall2023/"
imp.load_source("tvt", os.path.join(this_dir, "02_preprocessing_outliers.py"))
from tvt import training
from tvt import train1, val1, train2, val2, train3, val3, train4, val4, train5, val5, train6, val6
imp.load_source("universals", os.path.join(this_dir, "universal_functions.py"))
from universals import load_pickle_file, get_features_labels, predict_values, print_error_metrics
imp.load_source("vis", os.path.join(this_dir, "NeuralNetworks/vis_functions.py"))
from vis import create_scatter_plot

# %% [markdown]
# Load in models from pickle files

# %%
# model directory path
model_dir = '/Users/steeleb/OneDrive - Colostate/NASA-Northern/data/NN_train_val_test/models/VAE_overfit/'

histories = [f for f in os.listdir(model_dir) if 'history' in f]

history_1 = load_pickle_file(histories[0], model_dir)
history_2 = load_pickle_file(histories[1], model_dir)
history_3 = load_pickle_file(histories[2], model_dir)
history_4 = load_pickle_file(histories[3], model_dir)
history_5 = load_pickle_file(histories[4], model_dir)
history_6 = load_pickle_file(histories[5], model_dir)

# %% [markdown]
# And now we'll look at the training and validation loss and accuracy for each model

# %%
fig1, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history_1.history["loss"], label="training")
axs[0].plot(history_1.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(history_1.history["loss"], label="training")
axs[1].plot(history_1.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig1.suptitle("LOO dataset 1")
# Out:
# Text(0.5, 0.98, 'LOO dataset 1')

# %%
fig2, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history_2.history["loss"], label="training")
axs[0].plot(history_2.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(history_2.history["loss"], label="training")
axs[1].plot(history_2.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig2.suptitle("LOO dataset 2")
# Out:
# Text(0.5, 0.98, 'LOO dataset 2')

# %%
fig3, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history_3.history["loss"], label="training")
axs[0].plot(history_3.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(history_3.history["loss"], label="training")
axs[1].plot(history_3.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig3.suptitle("LOO dataset 3")
# Out:
# Text(0.5, 0.98, 'LOO dataset 3')

# %%
fig4, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history_4.history["loss"], label="training")
axs[0].plot(history_4.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(history_4.history["loss"], label="training")
axs[1].plot(history_4.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig4.suptitle("LOO dataset 4")
# Out:
# Text(0.5, 0.98, 'LOO dataset 4')

# %%
fig5, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history_5.history["loss"], label="training")
axs[0].plot(history_5.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(history_5.history["loss"], label="training")
axs[1].plot(history_5.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig5.suptitle("LOO dataset 5")
# Out:
# Text(0.5, 0.98, 'LOO dataset 5')

# %%
fig6, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(history_6.history["loss"], label="training")
axs[0].plot(history_6.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(history_6.history["loss"], label="training")
axs[1].plot(history_6.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig6.suptitle("LOO dataset 6")
# Out:
# Text(0.5, 0.98, 'LOO dataset 6')

# %%
fig1ts, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(ts_history_1.history["loss"], label="training")
axs[0].plot(ts_history_1.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(ts_history_1.history["loss"], label="training")
axs[1].plot(ts_history_1.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig1ts.suptitle("TS dataset 1")
# Out:
# Text(0.5, 0.98, 'TS dataset 1')

# %%
fig2ts, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(ts_history_2.history["loss"], label="training")
axs[0].plot(ts_history_2.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(ts_history_2.history["loss"], label="training")
axs[1].plot(ts_history_2.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig2ts.suptitle("TS dataset 2")
# Out:
# Text(0.5, 0.98, 'TS dataset 2')

# %%
fig3ts, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(ts_history_3.history["loss"], label="training")
axs[0].plot(ts_history_3.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(ts_history_3.history["loss"], label="training")
axs[1].plot(ts_history_3.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig3ts.suptitle("TS dataset 3")
# Out:
# Text(0.5, 0.98, 'TS dataset 3')

# %%
fig4ts, axs = plt.subplots(1, 2, figsize=(10, 4))

axs[0].plot(ts_history_4.history["loss"], label="training")
axs[0].plot(ts_history_4.history["val_loss"], label="validation")
axs[0].set_xlabel("Epoch")
axs[0].set_ylabel("Loss")
axs[0].legend()

axs[1].plot(ts_history_4.history["loss"], label="training")
axs[1].plot(ts_history_4.history["val_loss"], label="validation")
axs[1].set_xlabel("Epoch")
axs[1].set_ylabel("Loss")
axs[1].legend()

fig4ts.suptitle("TS dataset 4")
# Out:
# Text(0.5, 0.98, 'TS dataset 4')

# %% [markdown]
# Import data, models and look at actual values

# %%
features1, labels_1, val_features1, val_labels_1 = get_features_labels(train1, val1)
features2, labels_2, val_features2, val_labels_2 = get_features_labels(train2, val2)
features3, labels_3, val_features3, val_labels_3 = get_features_labels(train3, val3)
features4, labels_4, val_features4, val_labels_4 = get_features_labels(train4, val4)
features5, labels_5, val_features5, val_labels_5 = get_features_labels(train5, val5)
features6, labels_6, val_features6, val_labels_6 = get_features_labels(train6, val6)

ts_features1, ts_labels_1, ts_val_features1, ts_val_labels_1 = get_features_labels(train1_ts, val1_ts)
ts_features2, ts_labels_2, ts_val_features2, ts_val_labels_2 = get_features_labels(train2_ts, val2_ts)
ts_features3, ts_labels_3, ts_val_features3, ts_val_labels_3 = get_features_labels(train3_ts, val3_ts)
ts_features4, ts_labels_4, ts_val_features4, ts_val_labels_4 = get_features_labels(train4_ts, val4_ts)

# %%
models = [f for f in os.listdir(model_dir) if 'history' not in f]

ts_models = [f for f in models if 'ts' in f]
ts_models.sort()

models = [f for f in models if 'ts' not in f]
models.sort()

ts_model_1 = load_pickle_file(ts_models[0], model_dir)
ts_model_2 = load_pickle_file(ts_models[1], model_dir)
ts_model_3 = load_pickle_file(ts_models[2], model_dir)
ts_model_4 = load_pickle_file(ts_models[3], model_dir)

model_1 = load_pickle_file(models[0], model_dir)
model_2 = load_pickle_file(models[1], model_dir)
model_3 = load_pickle_file(models[2], model_dir)
model_4 = load_pickle_file(models[3], model_dir)
model_5 = load_pickle_file(models[4], model_dir)
model_6 = load_pickle_file(models[5], model_dir)

# %%
transform = pd.read_csv('/Users/steeleb/OneDrive - Colostate/NASA-Northern/data/NN_train_val_test/mean_std_training_v2023-11-09.csv')
transform.set_index(transform.columns[0], inplace=True)

t_mean = transform.loc['value']['mean']
t_std = transform.loc['value']['std']

# %%
# Call predict_values for each dataset
p_act_1, l_act_1, v_act_1, l_v_act_1 = predict_values(model_1, features1, val_features1, labels_1, val_labels_1, t_mean, t_std)
p_act_2, l_act_2, v_act_2, l_v_act_2 = predict_values(model_2, features2, val_features2, labels_2, val_labels_2, t_mean, t_std)
p_act_3, l_act_3, v_act_3, l_v_act_3 = predict_values(model_3, features3, val_features3, labels_3, val_labels_3, t_mean, t_std)
p_act_4, l_act_4, v_act_4, l_v_act_4 = predict_values(model_4, features4, val_features4, labels_4, val_labels_4, t_mean, t_std)
p_act_5, l_act_5, v_act_5, l_v_act_5 = predict_values(model_5, features5, val_features5, labels_5, val_labels_5, t_mean, t_std)
p_act_6, l_act_6, v_act_6, l_v_act_6 = predict_values(model_6, features6, val_features6, labels_6, val_labels_6, t_mean, t_std)

p_act_1_ts, l_act_1_ts, v_act_1_ts, l_v_act_1_ts = predict_values(ts_model_1, ts_features1, ts_val_features1, ts_labels_1, ts_val_labels_1, t_mean, t_std)
p_act_2_ts, l_act_2_ts, v_act_2_ts, l_v_act_2_ts = predict_values(ts_model_2, ts_features2, ts_val_features2, ts_labels_2, ts_val_labels_2, t_mean, t_std)
p_act_3_ts, l_act_3_ts, v_act_3_ts, l_v_act_3_ts = predict_values(ts_model_3, ts_features3, ts_val_features3, ts_labels_3, ts_val_labels_3, t_mean, t_std)
p_act_4_ts, l_act_4_ts, v_act_4_ts, l_v_act_4_ts = predict_values(ts_model_4, ts_features4, ts_val_features4, ts_labels_4, ts_val_labels_4, t_mean, t_std)
# Out:
# 63/63 [==============================] - 0s 2ms/step
#  1/10 [==>...........................] - ETA: 0s
# 2023-11-09 15:29:12.755792: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 10/10 [==============================] - 0s 4ms/step
# 53/53 [==============================] - 0s 2ms/step
#  1/20 [>.............................] - ETA: 0s
# 2023-11-09 15:29:13.044537: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 20/20 [==============================] - 0s 3ms/step
# 61/61 [==============================] - 0s 2ms/step
#  1/12 [=>............................] - ETA: 0s
# 2023-11-09 15:29:13.335967: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 12/12 [==============================] - 0s 3ms/step
# 62/62 [==============================] - 0s 2ms/step
# 2023-11-09 15:29:13.618943: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 11/11 [==============================] - 0s 3ms/step
# 59/59 [==============================] - 0s 2ms/step
#  1/14 [=>............................] - ETA: 0s
# 2023-11-09 15:29:13.907649: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 0s 3ms/step
# 64/64 [==============================] - 0s 2ms/step
# 2023-11-09 15:29:14.191609: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 9/9 [==============================] - 0s 4ms/step
# 59/59 [==============================] - 0s 2ms/step
#  1/14 [=>............................] - ETA: 0s
# 2023-11-09 15:29:14.496198: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 14/14 [==============================] - 0s 3ms/step
# 52/52 [==============================] - 0s 2ms/step
#  1/21 [>.............................] - ETA: 0s
# 2023-11-09 15:29:14.769318: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 21/21 [==============================] - 0s 3ms/step
# 50/50 [==============================] - 0s 2ms/step
#  1/22 [>.............................] - ETA: 1s
# 2023-11-09 15:29:15.039689: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2023-11-09 15:29:15.205251: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 22/22 [==============================] - 0s 3ms/step
# 56/56 [==============================] - 0s 2ms/step
#  1/16 [>.............................] - ETA: 0s
# 2023-11-09 15:29:15.336151: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 16/16 [==============================] - 0s 2ms/step

# %%
create_scatter_plot('Dataset 1', v_act_1, l_v_act_1, p_act_1, l_act_1)
create_scatter_plot('Dataset 2', v_act_2, l_v_act_2, p_act_2, l_act_2)
create_scatter_plot('Dataset 3', v_act_3, l_v_act_3, p_act_3, l_act_3)
create_scatter_plot('Dataset 4', v_act_4, l_v_act_4, p_act_4, l_act_4)
create_scatter_plot('Dataset 5', v_act_5, l_v_act_5, p_act_5, l_act_5)
create_scatter_plot('Dataset 6', v_act_6, l_v_act_6, p_act_6, l_act_6)

create_scatter_plot('Time Series Dataset 1', v_act_1_ts, l_v_act_1_ts, p_act_1_ts, l_act_1_ts)
create_scatter_plot('Time Series Dataset 2', v_act_2_ts, l_v_act_2_ts, p_act_2_ts, l_act_2_ts)
create_scatter_plot('Time Series Dataset 3', v_act_3_ts, l_v_act_3_ts, p_act_3_ts, l_act_3_ts)
create_scatter_plot('Time Series Dataset 4', v_act_4_ts, l_v_act_4_ts, p_act_4_ts, l_act_4_ts)

# %%
# loop through datasets 1-6
for i in range(1, 7):
    l_act = globals()["l_act_" + str(i)]
    p_act = globals()["p_act_" + str(i)]
    l_v_act = globals()["l_v_act_" + str(i)]
    v_act = globals()["v_act_" + str(i)]
    print_error_metrics(i, l_act, p_act, l_v_act, v_act)

# loop through time series datasets 1-4
for i in range(1, 5):
    ts_l_act = globals()["ts_l_act_" + str(i)]
    ts_p_act = globals()["ts_p_act_" + str(i)]
    ts_l_v_act = globals()["ts_l_v_act_" + str(i)]
    ts_v_act = globals()["ts_v_act_" + str(i)]
    print("TIME SERIES DATASET", i)
    print_error_metrics(i, ts_l_act, ts_p_act, ts_l_v_act, ts_v_act)
# Out:
# DATASET 1
# Mean Squared Error for Training Dataset 1 : 1.8070332884076707
# Mean Absolute Error for Training Dataset 1 : 1.0296995319989148
# Mean Squared Error for Validation Dataset 1 : 2.6339230153088913
# Mean Absolute Error for Validation Dataset 1 : 1.244251817694855
#
# DATASET 2
# Mean Squared Error for Training Dataset 2 : 2.156864013996362
# Mean Absolute Error for Training Dataset 2 : 1.1396178323921526
# Mean Squared Error for Validation Dataset 2 : 2.966363708339326
# Mean Absolute Error for Validation Dataset 2 : 1.322222625665657
#
# DATASET 3
# Mean Squared Error for Training Dataset 3 : 1.993890591538012
# Mean Absolute Error for Training Dataset 3 : 1.0735354178748575
# Mean Squared Error for Validation Dataset 3 : 3.5871862670081693
# Mean Absolute Error for Validation Dataset 3 : 1.512974955496828
#
# DATASET 4
# Mean Squared Error for Training Dataset 4 : 1.6558131707539054
# Mean Absolute Error for Training Dataset 4 : 0.9951600284193656
# Mean Squared Error for Validation Dataset 4 : 4.564375116423483
# Mean Absolute Error for Validation Dataset 4 : 1.6709748811026577
#
# DATASET 5
# Mean Squared Error for Training Dataset 5 : 1.8155209042260372
# Mean Absolute Error for Training Dataset 5 : 1.0207058895608323
# Mean Squared Error for Validation Dataset 5 : 2.1357257715049003
# Mean Absolute Error for Validation Dataset 5 : 1.1459141021434813
#
# DATASET 6
# Mean Squared Error for Training Dataset 6 : 1.810026875908982
# Mean Absolute Error for Training Dataset 6 : 1.0365351495486805
# Mean Squared Error for Validation Dataset 6 : 2.70955507171686
# Mean Absolute Error for Validation Dataset 6 : 1.3137273939483298
#
# TIME SERIES DATASET 1
# DATASET 1
# Mean Squared Error for Training Dataset 1 : 1.7998559812442663
# Mean Absolute Error for Training Dataset 1 : 1.0414102053959817
# Mean Squared Error for Validation Dataset 1 : 3.0916863777372714
# Mean Absolute Error for Validation Dataset 1 : 1.3392462570827919
#
# TIME SERIES DATASET 2
# DATASET 2
# Mean Squared Error for Training Dataset 2 : 2.25058372685209
# Mean Absolute Error for Training Dataset 2 : 1.156938569929493
# Mean Squared Error for Validation Dataset 2 : 2.416327464712509
# Mean Absolute Error for Validation Dataset 2 : 1.1663517614013028
#
# TIME SERIES DATASET 3
# DATASET 3
# Mean Squared Error for Training Dataset 3 : 2.1230668144884515
# Mean Absolute Error for Training Dataset 3 : 1.1283755895194552
# Mean Squared Error for Validation Dataset 3 : 2.506758323111704
# Mean Absolute Error for Validation Dataset 3 : 1.2121215647068766
#
# TIME SERIES DATASET 4
# DATASET 4
# Mean Squared Error for Training Dataset 4 : 2.306295773563191
# Mean Absolute Error for Training Dataset 4 : 1.1472861635521108
# Mean Squared Error for Validation Dataset 4 : 3.573194321499673
# Mean Absolute Error for Validation Dataset 4 : 1.503632732744665
